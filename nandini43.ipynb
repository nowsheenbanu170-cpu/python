# %%
a=int(input("enter a  number:"))
b=int (input("enter a number :"))
print('the value of A before swapping is:',a)
print('the value of A before swapping is:',b)
a,b=b,a
print('the value of A after swapping is:',a)
print('the value of A After swapping is:',b)
# Out:
# enter a  number:5
# enter a number :6
# the value of A before swapping is: 5
# the value of A before swapping is: 6
# the value of A after swapping is: 6
# the value of A After swapping is: 5

# %%
a=complex(input('enter a complex number for A:'))
b=complex (input('enter acomplex number for B:'))
add=a+b
mul=a*b
print("the sum is :",add)
print("the mul is:",mul)
# Out:
# enter a complex number for A:3+4j
# enter acomplex number for B:5+6j
# the sum is : (8+10j)
# the mul is: (-9+38j)

# %%
num=int(input("enter an integer:"))
for i in range (1,11):
    res=num*i
    print('{0} x {1} = {2}'.format (num,i,res))
# Out:
# enter an integer:20987
# 20987 x 1 = 20987
# 20987 x 2 = 41974
# 20987 x 3 = 62961
# 20987 x 4 = 83948
# 20987 x 5 = 104935
# 20987 x 6 = 125922
# 20987 x 7 = 146909
# 20987 x 8 = 167896
# 20987 x 9 = 188883
# 20987 x 10 = 209870

# %%
a=int(input("enter a  number for A:"))
b=int(input("enter a number  for B:"))
add=a+b
sub=a-b
mul=a*b
div=a/b
mod=a%b
print("the sum is:",add)
print("the difference is:",sub)
print("the product is:",mul)
print("the division is:",div)
print("the modulus is:",mod)
# Out:
# enter a  number for A:6
# enter a number  for B:5
# the sum is: 11
# the difference is: 1
# the product is: 30
# the division is: 1.2
# the modulus is: 1

# %%
a=3
b=5
print(a&b)
print(a|b)
print(~a)
print(a<<2)
print(b>>2)
# Out:
# 1
# 7
# -4
# 12
# 1

# %%
s='MTIET'
x='ES'
print(x in s)
# Out:
# False

# %%
s='PALAMANER'
x='ER'
print(x in s)
# Out:
# True

# %%
s1={12,3,4,5,4}
print(s1)
# Out:
# {5, 3, 12, 4}

# %%
x=5
print(x)
# Out:
# 5

# %%
x=5
x**=2
print(x)
# Out:
# 25

# %%
a=5
b=6
print(a==b)
print(a|b)
print(a<b)
print(a>b)
print(a<=)
